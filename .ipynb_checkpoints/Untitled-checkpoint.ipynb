# %%
import os
import cv2
import numpy as np
import scipy
from matplotlib import pyplot as plt
from PIL import Image

# %%
ez_image = ['2.jpg','20.jpg','24.jpg','28.jpg']
input_folder = './ez_image'

# %%
np_data = [cv2.imread(input_folder + "/" + f) for f in ez_image]

# %%
len(np_data)
# Out:
# 4

# %%
fig, m_axs = plt.subplots(4, 2, figsize=(15, 10))
bins_8bit = np.linspace(0, 255,26)
for (c_ax, d_ax), c_img in zip(m_axs, np_data):
    
    dst = cv2.fastNlMeansDenoisingColored(c_img,None,10,10,7,21)
    c_ax.imshow(c_img)
    #     gray_img = cv2.cvtColor(c_img, cv2.COLOR_BGR2GRAY)
    d_ax.hist(dst.ravel(), bins_8bit)

# %%
fig, m_axs = plt.subplots(4, 2, figsize=(15, 10))
for (c_ax, d_ax), img in zip(m_axs, np_data):
    gray_img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    dst = cv2.fastNlMeansDenoisingColored(img,None,10,10,7,21)
    c_ax.imshow(gray_img)
    d_ax.imshow(dst)

# %%
fig, m_axs = plt.subplots(4, 2, figsize=(15, 10))
for (c_ax, d_ax), img in zip(m_axs, np_data):
    print(img.shape)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     h,s = cv2.split(gray)
    thresh0 = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY_INV, 11, 2)
    contour, heirarchy = cv2.findContours(thresh0.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    cnts = sorted(contours, key = cv2.contourArea, reverse = True)
    for cnt in cnts:
        canvas_for_contours = thresh.copy()
        cv2.drawContours(thresh, cnts[:-1], 0, (0,255,0), 3)
        cv2.drawContours(canvas_for_contours, contours, 0, (0,255,0), 3)
    
    c_ax.imshow(img)
    d_ax.imshow(canvas_for_contours - thresh)
# Out:
# (209, 830, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-8042c8cb757b> in <module>
#       7     contour, heirarchy = cv2.findContours(thresh0.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
#       8     c_ax.imshow(img)
# ----> 9     d_ax.imshow(contour)
#      10
#
# ~/Documents/img_process/venv/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/Documents/img_process/venv/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/Documents/img_process/venv/lib/python3.6/site-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~/Documents/img_process/venv/lib/python3.6/site-packages/matplotlib/axes/_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5669                               resample=resample, **kwargs)
#    5670
# -> 5671         im.set_data(X)
#    5672         im.set_alpha(alpha)
#    5673         if im.get_clip_path() is None:
#
# ~/Documents/img_process/venv/lib/python3.6/site-packages/matplotlib/image.py in set_data(self, A)
#     683                 not np.can_cast(self._A.dtype, float, "same_kind")):
#     684             raise TypeError("Image data of dtype {} cannot be converted to "
# --> 685                             "float".format(self._A.dtype))
#     686
#     687         if not (self._A.ndim == 2
#
# TypeError: Image data of dtype object cannot be converted to float
